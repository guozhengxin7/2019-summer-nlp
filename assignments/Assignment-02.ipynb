# %% [markdown]
# # Machine Learning (Deep Learning)Based

# %% [markdown]
# # 1. Re-code the house price machine learning

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
import functools

# %%
data = datasets.load_boston()

# %% [markdown]
# 假设房价满足一个多元一次方程, $\theta$是方程的参数

# %%
def hypothesis(theta, X):
    """y = theta * x + b
    """
    if len(X.shape) == 2:
        return (X * theta).sum(1)
    else:
        return (X * theta).sum()

# %% [markdown]
# 使用均方损失，则代价函数为

# %% [markdown]
# $$J_{\theta} = \frac{1}{2m} \sum_{i=1}^m ( h_\theta(x^i) - y^i)^2 $$

# %%
def cost_func(X, y):
    """
    代价函数
    :param X:
    :param y:
    :return:
    """
    def f(theta):
        y_hat = hypothesis(theta, X)
        # 计算均方损失
        return np.sum(np.power((y - y_hat), 2))/len(y) / 2
    return f

# %% [markdown]
# 代价函数对自变量求导，单个$\theta$的偏导数为
# $$\begin{align}
# \frac{\partial }{\partial \theta_j} J(\theta_0,\theta_1,...,\theta_n) &= \frac{1}{2m} \sum_{i=1}^m ( h_\theta(x_0^i,x_1^i,x_2^i,...,x_n^i) - y^i)^2 d\theta_j \\
# &= \frac{1}{m} \sum_{i=1}^m ( h_\theta(x_0^i,x_1^i,x_2^i,...,x_n^i) - y^i)x_j^i
# \end{align}$$

# %%
def cost_func_gradient(X, y):
    """
    求代价函数的梯度
    :param X:
    :param y:
    :return:
    """
    def f(theta):
        m = len(X)
        partial_theta = []
        yhat = hypothesis(theta, X)
        for j, t in enumerate(theta):
            x_ij = [x[j] for x in X]
            pt = ((yhat - y) * x_ij).sum() / m
            partial_theta.append(pt)
        return np.array(partial_theta)
    return f

# %%
def computeNumericalGradient(loss_func, x):
    """
    使用极限来计算梯度，用于验证导数梯度的正确性
    :param loss_func:
    :param x:
    :return:
    """
    e = 1e-4;
    if isinstance(x, np.ndarray):
        numgrad = []
        for j, t in enumerate(x):
            perturb = np.zeros(x.shape)
            perturb[j] = e
            loss1 = loss_func(x - perturb)
            loss2 = loss_func(x + perturb)
            ng = (loss2 - loss1) / (2 * e);
            numgrad.append(ng)
        return np.array(numgrad)
    else:
        loss1 = loss_func(x - e)
        loss2 = loss_func(x + e)
        ng = (loss2 - loss1) / (2 * e)
        return ng

# %%
def get_random_theta(l):
    """
    随机初始化一个点
    :param l:
    :return:
    """
    import random
    return np.array([random.random() * 200 - 100 for i in range(0, l)])

# %%
X, y = data['data'], data['target']
feature_num = X.shape[1]
# 随机生成一些点计算梯度
thetas = [get_random_theta(feature_num) for i in range(0,10)]
numgrad = np.array([ computeNumericalGradient(cost_func(X, y), t) for t in thetas])
grad = np.array([ cost_func_gradient(X, y)(t) for t in thetas])

# %%
# 差别足够小则认为导函数是正确的

# %%
diff = np.linalg.norm(numgrad-grad)/np.linalg.norm(numgrad+grad)
diff
# Out:
# 3.672329390160159e-11

# %%
def gradient_descent(start, f, df, learning_rate=0.1, max_iter=1000, accuracy = 0.001):
    # 批量梯度下降
    x = start
    num_iter = 0
    lastValue = np.inf
    trace_point = []
    while num_iter <= max_iter:
        v = f(x)
        print("num_iter = %f, v  = %f" % (num_iter, v))
        trace_point.append((x, v))
        diff = abs(v - lastValue)
        if diff <= accuracy:
            break
        lastValue = v
        g = df(x)
        x = x - learning_rate * g
        num_iter += 1
    return x, np.array(trace_point)

# %%
X, y = data['data'], data['target']
b = np.ones(len(X))
# 把自变量归一化一下
X = (X-X.min(0))/(X.max(0)-X.min(0))
X = np.column_stack((X,b))

# %%
sns.distplot(y)

# %%
feature_num = X.shape[1]
start_theta = get_random_theta(feature_num)
extremum_theta, traces = gradient_descent(start_theta, cost_func(X, y), functools.partial(computeNumericalGradient, cost_func(X, y)), max_iter=200, learning_rate=0.1)
# Out:
# num_iter = 0.000000, v  = 16405.669685
# num_iter = 1.000000, v  = 7927.452108
# num_iter = 2.000000, v  = 4563.136096
# num_iter = 3.000000, v  = 3187.624563
# num_iter = 4.000000, v  = 2588.173690
# num_iter = 5.000000, v  = 2293.981996
# num_iter = 6.000000, v  = 2122.114074
# num_iter = 7.000000, v  = 2001.334913
# num_iter = 8.000000, v  = 1903.763012
# num_iter = 9.000000, v  = 1818.353168
# num_iter = 10.000000, v  = 1740.607643
# num_iter = 11.000000, v  = 1668.583431
# num_iter = 12.000000, v  = 1601.342216
# num_iter = 13.000000, v  = 1538.348090
# num_iter = 14.000000, v  = 1479.233023
# num_iter = 15.000000, v  = 1423.705061
# num_iter = 16.000000, v  = 1371.511966
# num_iter = 17.000000, v  = 1322.426402
# num_iter = 18.000000, v  = 1276.239539
# num_iter = 19.000000, v  = 1232.757963
# num_iter = 20.000000, v  = 1191.801909
# num_iter = 21.000000, v  = 1153.204057
# num_iter = 22.000000, v  = 1116.808561
# num_iter = 23.000000, v  = 1082.470228
# num_iter = 24.000000, v  = 1050.053767
# num_iter = 25.000000, v  = 1019.433104
# num_iter = 26.000000, v  = 990.490745
# num_iter = 27.000000, v  = 963.117188
# num_iter = 28.000000, v  = 937.210376
# num_iter = 29.000000, v  = 912.675180
# num_iter = 30.000000, v  = 889.422930
# num_iter = 31.000000, v  = 867.370969
# num_iter = 32.000000, v  = 846.442240
# num_iter = 33.000000, v  = 826.564904
# num_iter = 34.000000, v  = 807.671981
# num_iter = 35.000000, v  = 789.701017
# num_iter = 36.000000, v  = 772.593774
# num_iter = 37.000000, v  = 756.295942
# num_iter = 38.000000, v  = 740.756868
# num_iter = 39.000000, v  = 725.929310
# num_iter = 40.000000, v  = 711.769197
# num_iter = 41.000000, v  = 698.235417
# num_iter = 42.000000, v  = 685.289613
# num_iter = 43.000000, v  = 672.895995
# num_iter = 44.000000, v  = 661.021163
# num_iter = 45.000000, v  = 649.633946
# num_iter = 46.000000, v  = 638.705249
# num_iter = 47.000000, v  = 628.207910
# num_iter = 48.000000, v  = 618.116568
# num_iter = 49.000000, v  = 608.407545
# num_iter = 50.000000, v  = 599.058722
# num_iter = 51.000000, v  = 590.049442
# num_iter = 52.000000, v  = 581.360406
# num_iter = 53.000000, v  = 572.973581
# num_iter = 54.000000, v  = 564.872112
# num_iter = 55.000000, v  = 557.040246
# num_iter = 56.000000, v  = 549.463255
# num_iter = 57.000000, v  = 542.127367
# num_iter = 58.000000, v  = 535.019698
# num_iter = 59.000000, v  = 528.128197
# num_iter = 60.000000, v  = 521.441587
# num_iter = 61.000000, v  = 514.949310
# num_iter = 62.000000, v  = 508.641484
# num_iter = 63.000000, v  = 502.508853
# num_iter = 64.000000, v  = 496.542747
# num_iter = 65.000000, v  = 490.735040
# num_iter = 66.000000, v  = 485.078117
# num_iter = 67.000000, v  = 479.564836
# num_iter = 68.000000, v  = 474.188500
# num_iter = 69.000000, v  = 468.942822
# num_iter = 70.000000, v  = 463.821903
# num_iter = 71.000000, v  = 458.820204
# num_iter = 72.000000, v  = 453.932519
# num_iter = 73.000000, v  = 449.153959
# num_iter = 74.000000, v  = 444.479924
# num_iter = 75.000000, v  = 439.906090
# num_iter = 76.000000, v  = 435.428386
# num_iter = 77.000000, v  = 431.042979
# num_iter = 78.000000, v  = 426.746261
# num_iter = 79.000000, v  = 422.534827
# num_iter = 80.000000, v  = 418.405472
# num_iter = 81.000000, v  = 414.355168
# num_iter = 82.000000, v  = 410.381057
# num_iter = 83.000000, v  = 406.480442
# num_iter = 84.000000, v  = 402.650771
# num_iter = 85.000000, v  = 398.889633
# num_iter = 86.000000, v  = 395.194746
# num_iter = 87.000000, v  = 391.563948
# num_iter = 88.000000, v  = 387.995191
# num_iter = 89.000000, v  = 384.486536
# num_iter = 90.000000, v  = 381.036138
# num_iter = 91.000000, v  = 377.642252
# num_iter = 92.000000, v  = 374.303213
# num_iter = 93.000000, v  = 371.017444
# num_iter = 94.000000, v  = 367.783442
# num_iter = 95.000000, v  = 364.599775
# num_iter = 96.000000, v  = 361.465080
# num_iter = 97.000000, v  = 358.378056
# num_iter = 98.000000, v  = 355.337464
# num_iter = 99.000000, v  = 352.342118
# num_iter = 100.000000, v  = 349.390886
# num_iter = 101.000000, v  = 346.482684
# num_iter = 102.000000, v  = 343.616476
# num_iter = 103.000000, v  = 340.791268
# num_iter = 104.000000, v  = 338.006109
# num_iter = 105.000000, v  = 335.260084
# num_iter = 106.000000, v  = 332.552317
# num_iter = 107.000000, v  = 329.881965
# num_iter = 108.000000, v  = 327.248216
# num_iter = 109.000000, v  = 324.650292
# num_iter = 110.000000, v  = 322.087440
# num_iter = 111.000000, v  = 319.558937
# num_iter = 112.000000, v  = 317.064085
# num_iter = 113.000000, v  = 314.602210
# num_iter = 114.000000, v  = 312.172661
# num_iter = 115.000000, v  = 309.774808
# num_iter = 116.000000, v  = 307.408044
# num_iter = 117.000000, v  = 305.071779
# num_iter = 118.000000, v  = 302.765443
# num_iter = 119.000000, v  = 300.488484
# num_iter = 120.000000, v  = 298.240366
# num_iter = 121.000000, v  = 296.020568
# num_iter = 122.000000, v  = 293.828587
# num_iter = 123.000000, v  = 291.663931
# num_iter = 124.000000, v  = 289.526125
# num_iter = 125.000000, v  = 287.414705
# num_iter = 126.000000, v  = 285.329219
# num_iter = 127.000000, v  = 283.269229
# num_iter = 128.000000, v  = 281.234308
# num_iter = 129.000000, v  = 279.224039
# num_iter = 130.000000, v  = 277.238015
# num_iter = 131.000000, v  = 275.275840
# num_iter = 132.000000, v  = 273.337129
# num_iter = 133.000000, v  = 271.421503
# num_iter = 134.000000, v  = 269.528594
# num_iter = 135.000000, v  = 267.658042
# num_iter = 136.000000, v  = 265.809495
# num_iter = 137.000000, v  = 263.982610
# num_iter = 138.000000, v  = 262.177050
# num_iter = 139.000000, v  = 260.392485
# num_iter = 140.000000, v  = 258.628594
# num_iter = 141.000000, v  = 256.885061
# num_iter = 142.000000, v  = 255.161578
# num_iter = 143.000000, v  = 253.457842
# num_iter = 144.000000, v  = 251.773557
# num_iter = 145.000000, v  = 250.108432
# num_iter = 146.000000, v  = 248.462183
# num_iter = 147.000000, v  = 246.834530
# num_iter = 148.000000, v  = 245.225200
# num_iter = 149.000000, v  = 243.633924
# num_iter = 150.000000, v  = 242.060440
# num_iter = 151.000000, v  = 240.504487
# num_iter = 152.000000, v  = 238.965813
# num_iter = 153.000000, v  = 237.444169
# num_iter = 154.000000, v  = 235.939309
# num_iter = 155.000000, v  = 234.450993
# num_iter = 156.000000, v  = 232.978986
# num_iter = 157.000000, v  = 231.523056
# num_iter = 158.000000, v  = 230.082975
# num_iter = 159.000000, v  = 228.658519
# num_iter = 160.000000, v  = 227.249469
# num_iter = 161.000000, v  = 225.855608
# num_iter = 162.000000, v  = 224.476723
# num_iter = 163.000000, v  = 223.112606
# num_iter = 164.000000, v  = 221.763052
# num_iter = 165.000000, v  = 220.427859
# num_iter = 166.000000, v  = 219.106827
# num_iter = 167.000000, v  = 217.799762
# num_iter = 168.000000, v  = 216.506472
# num_iter = 169.000000, v  = 215.226767
# num_iter = 170.000000, v  = 213.960462
# num_iter = 171.000000, v  = 212.707373
# num_iter = 172.000000, v  = 211.467321
# num_iter = 173.000000, v  = 210.240129
# num_iter = 174.000000, v  = 209.025622
# num_iter = 175.000000, v  = 207.823629
# num_iter = 176.000000, v  = 206.633980
# num_iter = 177.000000, v  = 205.456511
# num_iter = 178.000000, v  = 204.291057
# num_iter = 179.000000, v  = 203.137457
# num_iter = 180.000000, v  = 201.995553
# num_iter = 181.000000, v  = 200.865189
# num_iter = 182.000000, v  = 199.746211
# num_iter = 183.000000, v  = 198.638467
# num_iter = 184.000000, v  = 197.541810
# num_iter = 185.000000, v  = 196.456092
# num_iter = 186.000000, v  = 195.381169
# num_iter = 187.000000, v  = 194.316899
# num_iter = 188.000000, v  = 193.263141
# num_iter = 189.000000, v  = 192.219759
# num_iter = 190.000000, v  = 191.186615
# num_iter = 191.000000, v  = 190.163576
# num_iter = 192.000000, v  = 189.150510
# num_iter = 193.000000, v  = 188.147288
# num_iter = 194.000000, v  = 187.153782
# num_iter = 195.000000, v  = 186.169865
# num_iter = 196.000000, v  = 185.195414
# num_iter = 341.000000, v  = 103.515004
# num_iter = 342.000000, v  = 103.190185
# num_iter = 343.000000, v  = 102.867213
# num_iter = 344.000000, v  = 102.546073
# num_iter = 345.000000, v  = 102.226747
# num_iter = 346.000000, v  = 101.909220
# num_iter = 347.000000, v  = 101.593474
# num_iter = 348.000000, v  = 101.279495
# num_iter = 349.000000, v  = 100.967265
# num_iter = 350.000000, v  = 100.656770
# num_iter = 351.000000, v  = 100.347994
# num_iter = 352.000000, v  = 100.040922
# num_iter = 353.000000, v  = 99.735538
# num_iter = 354.000000, v  = 99.431828
# num_iter = 355.000000, v  = 99.129778
# num_iter = 356.000000, v  = 98.829372
# num_iter = 357.000000, v  = 98.530596
# num_iter = 358.000000, v  = 98.233436
# num_iter = 359.000000, v  = 97.937878
# num_iter = 360.000000, v  = 97.643908
# num_iter = 361.000000, v  = 97.351512
# num_iter = 362.000000, v  = 97.060677
# num_iter = 363.000000, v  = 96.771390
# num_iter = 364.000000, v  = 96.483637
# num_iter = 365.000000, v  = 96.197404
# num_iter = 366.000000, v  = 95.912680
# num_iter = 367.000000, v  = 95.629451
# num_iter = 368.000000, v  = 95.347705
# num_iter = 369.000000, v  = 95.067429
# num_iter = 370.000000, v  = 94.788611
# num_iter = 371.000000, v  = 94.511239
# num_iter = 372.000000, v  = 94.235300
# num_iter = 373.000000, v  = 93.960783
# num_iter = 374.000000, v  = 93.687676
# num_iter = 375.000000, v  = 93.415966
# num_iter = 376.000000, v  = 93.145644
# num_iter = 377.000000, v  = 92.876697
# num_iter = 378.000000, v  = 92.609113
# num_iter = 379.000000, v  = 92.342883
# num_iter = 380.000000, v  = 92.077994
# num_iter = 381.000000, v  = 91.814436
# num_iter = 382.000000, v  = 91.552199
# num_iter = 383.000000, v  = 91.291271
# num_iter = 384.000000, v  = 91.031642
# num_iter = 385.000000, v  = 90.773301
# num_iter = 386.000000, v  = 90.516239
# num_iter = 387.000000, v  = 90.260445
# num_iter = 388.000000, v  = 90.005908
# num_iter = 389.000000, v  = 89.752620
# num_iter = 390.000000, v  = 89.500570
# num_iter = 391.000000, v  = 89.249749
# num_iter = 392.000000, v  = 89.000146
# num_iter = 393.000000, v  = 88.751752
# num_iter = 394.000000, v  = 88.504559
# num_iter = 395.000000, v  = 88.258556
# num_iter = 396.000000, v  = 88.013734
# num_iter = 397.000000, v  = 87.770085
# num_iter = 398.000000, v  = 87.527598
# num_iter = 399.000000, v  = 87.286266
# num_iter = 400.000000, v  = 87.046080
# num_iter = 401.000000, v  = 86.807030
# num_iter = 402.000000, v  = 86.569108
# num_iter = 403.000000, v  = 86.332305
# num_iter = 404.000000, v  = 86.096614
# num_iter = 405.000000, v  = 85.862025
# num_iter = 406.000000, v  = 85.628531
# num_iter = 407.000000, v  = 85.396123
# num_iter = 408.000000, v  = 85.164793
# num_iter = 409.000000, v  = 84.934534
# num_iter = 410.000000, v  = 84.705336
# num_iter = 411.000000, v  = 84.477193
# num_iter = 628.000000, v  = 51.375443
# num_iter = 629.000000, v  = 51.273585
# num_iter = 630.000000, v  = 51.172046
# num_iter = 631.000000, v  = 51.070823
# num_iter = 632.000000, v  = 50.969916
# num_iter = 633.000000, v  = 50.869324
# num_iter = 634.000000, v  = 50.769044
# num_iter = 635.000000, v  = 50.669076
# num_iter = 636.000000, v  = 50.569419
# num_iter = 637.000000, v  = 50.470071
# num_iter = 638.000000, v  = 50.371031
# num_iter = 639.000000, v  = 50.272298
# num_iter = 640.000000, v  = 50.173870
# num_iter = 641.000000, v  = 50.075747
# num_iter = 642.000000, v  = 49.977926
# num_iter = 643.000000, v  = 49.880407
# num_iter = 644.000000, v  = 49.783189
# num_iter = 645.000000, v  = 49.686270
# num_iter = 646.000000, v  = 49.589649
# num_iter = 647.000000, v  = 49.493326
# num_iter = 648.000000, v  = 49.397297
# num_iter = 649.000000, v  = 49.301564
# num_iter = 650.000000, v  = 49.206124
# num_iter = 651.000000, v  = 49.110976
# num_iter = 652.000000, v  = 49.016118
# num_iter = 653.000000, v  = 48.921551
# num_iter = 654.000000, v  = 48.827273
# num_iter = 655.000000, v  = 48.733282
# num_iter = 656.000000, v  = 48.639577
# num_iter = 657.000000, v  = 48.546158
# num_iter = 658.000000, v  = 48.453023
# num_iter = 659.000000, v  = 48.360171
# num_iter = 660.000000, v  = 48.267601
# num_iter = 661.000000, v  = 48.175312
# num_iter = 662.000000, v  = 48.083302
# num_iter = 663.000000, v  = 47.991571
# num_iter = 664.000000, v  = 47.900118
# num_iter = 665.000000, v  = 47.808941
# num_iter = 666.000000, v  = 47.718039
# num_iter = 667.000000, v  = 47.627412
# num_iter = 668.000000, v  = 47.537058
# num_iter = 669.000000, v  = 47.446976
# num_iter = 670.000000, v  = 47.357165
# num_iter = 671.000000, v  = 47.267624
# num_iter = 672.000000, v  = 47.178352
# num_iter = 673.000000, v  = 47.089348
# num_iter = 674.000000, v  = 47.000611
# num_iter = 675.000000, v  = 46.912140
# num_iter = 676.000000, v  = 46.823934
# num_iter = 677.000000, v  = 46.735991
# num_iter = 678.000000, v  = 46.648312
# num_iter = 679.000000, v  = 46.560894
# num_iter = 680.000000, v  = 46.473737
# num_iter = 681.000000, v  = 46.386840
# num_iter = 682.000000, v  = 46.300202
# num_iter = 683.000000, v  = 46.213822
# num_iter = 684.000000, v  = 46.127698
# num_iter = 685.000000, v  = 46.041831
# num_iter = 686.000000, v  = 45.956218
# num_iter = 687.000000, v  = 45.870860
# num_iter = 688.000000, v  = 45.785754
# num_iter = 689.000000, v  = 45.700900
# num_iter = 690.000000, v  = 45.616298
# num_iter = 691.000000, v  = 45.531946
# num_iter = 692.000000, v  = 45.447843
# num_iter = 693.000000, v  = 45.363988
# num_iter = 694.000000, v  = 45.280380
# num_iter = 695.000000, v  = 45.197019
# num_iter = 696.000000, v  = 45.113904
# num_iter = 697.000000, v  = 45.031033
# num_iter = 698.000000, v  = 44.948406
# num_iter = 699.000000, v  = 44.866021
# num_iter = 771.000000, v  = 39.518549
# num_iter = 772.000000, v  = 39.451710
# num_iter = 773.000000, v  = 39.385056
# num_iter = 774.000000, v  = 39.318589
# num_iter = 775.000000, v  = 39.252306
# num_iter = 776.000000, v  = 39.186208
# num_iter = 777.000000, v  = 39.120294
# num_iter = 778.000000, v  = 39.054563
# num_iter = 779.000000, v  = 38.989015
# num_iter = 780.000000, v  = 38.923649
# num_iter = 781.000000, v  = 38.858464
# num_iter = 782.000000, v  = 38.793460
# num_iter = 783.000000, v  = 38.728637
# num_iter = 784.000000, v  = 38.663993
# num_iter = 785.000000, v  = 38.599527
# num_iter = 786.000000, v  = 38.535240
# num_iter = 787.000000, v  = 38.471131
# num_iter = 788.000000, v  = 38.407199
# num_iter = 789.000000, v  = 38.343444
# num_iter = 790.000000, v  = 38.279865
# num_iter = 791.000000, v  = 38.216461
# num_iter = 792.000000, v  = 38.153231
# num_iter = 793.000000, v  = 38.090176
# num_iter = 794.000000, v  = 38.027295
# num_iter = 795.000000, v  = 37.964586
# num_iter = 796.000000, v  = 37.902051
# num_iter = 797.000000, v  = 37.839686
# num_iter = 798.000000, v  = 37.777494
# num_iter = 799.000000, v  = 37.715472
# num_iter = 800.000000, v  = 37.653620
# num_iter = 801.000000, v  = 37.591937
# num_iter = 802.000000, v  = 37.530424
# num_iter = 803.000000, v  = 37.469079
# num_iter = 804.000000, v  = 37.407902
# num_iter = 805.000000, v  = 37.346893
# num_iter = 806.000000, v  = 37.286050
# num_iter = 807.000000, v  = 37.225373
# num_iter = 808.000000, v  = 37.164862
# num_iter = 809.000000, v  = 37.104517
# num_iter = 810.000000, v  = 37.044336
# num_iter = 811.000000, v  = 36.984319
# num_iter = 812.000000, v  = 36.924465
# num_iter = 813.000000, v  = 36.864774
# num_iter = 814.000000, v  = 36.805246
# num_iter = 815.000000, v  = 36.745880
# num_iter = 816.000000, v  = 36.686675
# num_iter = 817.000000, v  = 36.627631
# num_iter = 818.000000, v  = 36.568747
# num_iter = 819.000000, v  = 36.510023
# num_iter = 820.000000, v  = 36.451458
# num_iter = 821.000000, v  = 36.393052
# num_iter = 822.000000, v  = 36.334804
# num_iter = 823.000000, v  = 36.276714
# num_iter = 824.000000, v  = 36.218781
# num_iter = 825.000000, v  = 36.161005
# num_iter = 826.000000, v  = 36.103385
# num_iter = 827.000000, v  = 36.045920
# num_iter = 828.000000, v  = 35.988611
# num_iter = 829.000000, v  = 35.931456
# num_iter = 830.000000, v  = 35.874456
# num_iter = 831.000000, v  = 35.817609
# num_iter = 832.000000, v  = 35.760915
# num_iter = 833.000000, v  = 35.704374
# num_iter = 834.000000, v  = 35.647985
# num_iter = 835.000000, v  = 35.591747
# num_iter = 836.000000, v  = 35.535661
# num_iter = 837.000000, v  = 35.479726
# num_iter = 838.000000, v  = 35.423940
# num_iter = 839.000000, v  = 35.368304
# num_iter = 840.000000, v  = 35.312818
# num_iter = 841.000000, v  = 35.257480
# num_iter = 842.000000, v  = 35.202291
# num_iter = 843.000000, v  = 35.147249
# num_iter = 844.000000, v  = 35.092355
# num_iter = 845.000000, v  = 35.037607
# num_iter = 846.000000, v  = 34.983006
# num_iter = 847.000000, v  = 34.928550
# num_iter = 848.000000, v  = 34.874240
# num_iter = 849.000000, v  = 34.820075
# num_iter = 850.000000, v  = 34.766055
# num_iter = 851.000000, v  = 34.712179
# num_iter = 852.000000, v  = 34.658446
# num_iter = 853.000000, v  = 34.604856
# num_iter = 854.000000, v  = 34.551409
# num_iter = 855.000000, v  = 34.498104
# num_iter = 856.000000, v  = 34.444941
# num_iter = 857.000000, v  = 34.391919
# num_iter = 858.000000, v  = 34.339038
# num_iter = 859.000000, v  = 34.286297
# num_iter = 860.000000, v  = 34.233696
# num_iter = 861.000000, v  = 34.181235
# num_iter = 862.000000, v  = 34.128913
# num_iter = 863.000000, v  = 34.076729
# num_iter = 864.000000, v  = 34.024684
# num_iter = 865.000000, v  = 33.972776
# num_iter = 866.000000, v  = 33.921006
# num_iter = 867.000000, v  = 33.869372
# num_iter = 868.000000, v  = 33.817875
# num_iter = 869.000000, v  = 33.766514
# num_iter = 870.000000, v  = 33.715289
# num_iter = 871.000000, v  = 33.664199
# num_iter = 872.000000, v  = 33.613243
# num_iter = 873.000000, v  = 33.562422
# num_iter = 874.000000, v  = 33.511735
# num_iter = 875.000000, v  = 33.461181
# num_iter = 876.000000, v  = 33.410760
# num_iter = 877.000000, v  = 33.360472
# num_iter = 878.000000, v  = 33.310316
# num_iter = 879.000000, v  = 33.260292
# num_iter = 880.000000, v  = 33.210399
# num_iter = 881.000000, v  = 33.160637
# num_iter = 882.000000, v  = 33.111006
# num_iter = 883.000000, v  = 33.061505
# num_iter = 884.000000, v  = 33.012133
# num_iter = 885.000000, v  = 32.962891
# num_iter = 886.000000, v  = 32.913778
# num_iter = 887.000000, v  = 32.864793
# num_iter = 888.000000, v  = 32.815937
# num_iter = 889.000000, v  = 32.767208
# num_iter = 890.000000, v  = 32.718607
# num_iter = 891.000000, v  = 32.670133
# num_iter = 892.000000, v  = 32.621785
# num_iter = 893.000000, v  = 32.573563
# num_iter = 894.000000, v  = 32.525467
# num_iter = 895.000000, v  = 32.477497
# num_iter = 896.000000, v  = 32.429651
# num_iter = 897.000000, v  = 32.381930
# num_iter = 898.000000, v  = 32.334333
# num_iter = 899.000000, v  = 32.286860
# num_iter = 900.000000, v  = 32.239511
# num_iter = 901.000000, v  = 32.192284
# num_iter = 902.000000, v  = 32.145181
# num_iter = 903.000000, v  = 32.098199
# num_iter = 904.000000, v  = 32.051340
# num_iter = 905.000000, v  = 32.004602
# num_iter = 906.000000, v  = 31.957985
# num_iter = 907.000000, v  = 31.911489
# num_iter = 908.000000, v  = 31.865114
# num_iter = 909.000000, v  = 31.818858
# num_iter = 910.000000, v  = 31.772723
# num_iter = 911.000000, v  = 31.726706
# num_iter = 912.000000, v  = 31.680809
# num_iter = 913.000000, v  = 31.635030
# num_iter = 914.000000, v  = 31.589370
# num_iter = 987.000000, v  = 28.552627
# num_iter = 988.000000, v  = 28.514797
# num_iter = 989.000000, v  = 28.477060
# num_iter = 990.000000, v  = 28.439418
# num_iter = 991.000000, v  = 28.401870
# num_iter = 992.000000, v  = 28.364415
# num_iter = 993.000000, v  = 28.327054
# num_iter = 994.000000, v  = 28.289786
# num_iter = 995.000000, v  = 28.252610
# num_iter = 996.000000, v  = 28.215527
# num_iter = 997.000000, v  = 28.178537
# num_iter = 998.000000, v  = 28.141638
# num_iter = 999.000000, v  = 28.104831
# num_iter = 1000.000000, v  = 28.068116

# %% [markdown]
# ## 求解的参数为

# %%
extremum_theta
# Out:
# array([ -3.22082153,  18.81384647,  10.45465447,   3.47066594,
#        -37.33336946,  44.79010671,   1.79599176, -42.82324733,
#         -0.45994074,   2.83483718,  -4.8473935 ,  13.6950109 ,
#          1.91369631,   3.92009337])

# %% [markdown]
# # 2. Answer following questions

# %% [markdown]
# 1. Why do we need machine learning methods instead of creating a complicated formula?
#
# Ans: 机器能够自动跟随变化的数据重建公式，而且可以可以生成一些非常复杂人力很难直观理解的公式，而这些人类很难做到

# %% [markdown]
# 2. Wha't's the disadvantages of the 1st Random Choosen methods in our course?
#
# Ans: 随机选择参数的话，没有目的性，很难找到真的解

# %% [markdown]
# 3. Is the 2nd method supervised direction better than 1st one? What's the disadvantages of the 2nd supversied directin method?
#
# Ans: 第二种方法优于第一种方法，但是它只能知道大概的前进方向，却不知道精确的方向。

# %% [markdown]
# 4. Why do we use Derivative / Gredient to fit a target function?
#
# Ans: 梯度即各个自变量的偏导数组成的偏导向量，梯度的方向即函数增长最快的方向，反之，梯度的反方向即是函数值下降最快的方向。使用梯度下降来求解损失函数的最小值，其最小值的点也就是损失函数拟合得最好的点。

# %% [markdown]
# 5. In the words 'Gredient Descent', what's the Gredient and what's the Descent?
#
# Ans: 梯度即各个自变量的偏导数组成的偏导向量，梯度的方向即函数增长最快的方向，反之，梯度的反方向即是函数值下降最快的方向。

# %% [markdown]
# 6. What's the advantages of the 3rd gradient descent method compared to the previous methods?
#
# Ans: 梯度下降能够精确的知道当前位置函数值减少最快的方向，不用盲目的去做无用的尝试，可以很快的找到损失函数的极值点。

# %% [markdown]
# 7. Using the simple words to describe: What's the machine leanring.
#
# Ans: 机器学习就是让机器从数据中学习一种方法以解决特定的问题，并且随着数据的增多，机器学到的方法的性能也随之提高。

# %% [markdown]
# # 3. Finish the search problem

# %%
# 爬取深圳地铁站点

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait

# %%
url = "http://www.szmc.net/ver2/operating/search"

# %%
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
driver = webdriver.Chrome(options=chrome_options)
driver.implicitly_wait(10)

# %%
driver.get(url)

# %%
lines = [(a.get_attribute("href"), a.find_element_by_tag_name("span").text) for a in driver.find_element_by_class_name("xianlu").find_elements_by_tag_name("a")]

# %%
lines
# Out:
# [('http://www.szmc.net/ver2/operating/search?scode=0101&xl=1', '1号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0201&xl=2', '2号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0301&xl=3', '3号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0401&xl=4', '4号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0501&xl=5', '5号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0601&xl=6', '7号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0701&xl=7', '9号线'),
#  ('http://www.szmc.net/ver2/operating/search?scode=0801&xl=8', '11号线')]

# %%
subway_sites = {}
for site_url, site_name in lines:
    driver.get(site_url)
    subway_sites[site_name] = [s.text for s in driver.find_element_by_id("siteList").find_elements_by_tag_name("a")]

# %%
# 构建地铁图
subway_site_map = {}
for line_name, sites in subway_sites.items():
    for i in range(0, len(sites)):
        if not subway_site_map.get(sites[i]):
            subway_site_map[sites[i]] = {} 
            subway_site_map[sites[i]]['line'] = set()
        if not subway_site_map[sites[i]].get("neighbours"):
            subway_site_map[sites[i]]['neighbours'] = {}
        subway_site_map[sites[i]]['line'].add(line_name)
        if i < len(sites) - 1:
            subway_site_map[sites[i]]['neighbours'][sites[i + 1]] = {"line": line_name}
        if i > 0:
            subway_site_map[sites[i]]['neighbours'][sites[i - 1]] = {"line": line_name}

# %%
subway_site_map['世界之窗站']
# Out:
# {'line': {'1号线', '2号线'},
#  'neighbours': {'白石洲站': {'line': '1号线'},
#   '华侨城站': {'line': '1号线'},
#   '侨城北站': {'line': '2号线'},
#   '红树湾站': {'line': '2号线'}}}

# %%
subway_site_map['安托山站']
# Out:
# {'line': {'2号线', '7号线'},
#  'neighbours': {'侨香站': {'line': '2号线'},
#   '深康站': {'line': '2号线'},
#   '农林站': {'line': '7号线'},
#   '深云站': {'line': '7号线'}}}

# %%
subway_site_map['民乐站']
# Out:
# {'line': {'4号线'},
#  'neighbours': {'白石龙站': {'line': '4号线'}, '上梅林站': {'line': '4号线'}}}

# %%
subway_site_map
# Out:
# {'罗湖站': {'line': {'1号线'}, 'neighbours': {'国贸站': {'line': '1号线'}}},
#  '国贸站': {'line': {'1号线'},
#   'neighbours': {'老街站': {'line': '1号线'}, '罗湖站': {'line': '1号线'}}},
#  '老街站': {'line': {'1号线', '3号线'},
#   'neighbours': {'大剧院站': {'line': '1号线'},
#    '国贸站': {'line': '1号线'},
#    '晒布站': {'line': '3号线'},
#    '红岭站': {'line': '3号线'}}},
#  '大剧院站': {'line': {'1号线', '2号线'},
#   'neighbours': {'科学馆站': {'line': '1号线'},
#    '老街站': {'line': '1号线'},
#    '湖贝站': {'line': '2号线'},
#    '燕南站': {'line': '2号线'}}},
#  '科学馆站': {'line': {'1号线'},
#   'neighbours': {'华强路站': {'line': '1号线'}, '大剧院站': {'line': '1号线'}}},
#  '华强路站': {'line': {'1号线'},
#   'neighbours': {'岗厦站': {'line': '1号线'}, '科学馆站': {'line': '1号线'}}},
#  '岗厦站': {'line': {'1号线'},
#   'neighbours': {'会展中心站': {'line': '1号线'}, '华强路站': {'line': '1号线'}}},
#  '会展中心站': {'line': {'1号线', '4号线'},
#   'neighbours': {'购物公园站': {'line': '1号线'},
#    '岗厦站': {'line': '1号线'},
#    '市民中心站': {'line': '4号线'},
#    '福民站': {'line': '4号线'}}},
#  '购物公园站': {'line': {'1号线', '3号线'},
#   'neighbours': {'香蜜湖站': {'line': '1号线'},
#    '会展中心站': {'line': '1号线'},
#    '福田站': {'line': '3号线'},
#    '石厦站': {'line': '3号线'}}},
#  '香蜜湖站': {'line': {'1号线'},
#   'neighbours': {'车公庙站': {'line': '1号线'}, '购物公园站': {'line': '1号线'}}},
#  '车公庙站': {'line': {'11号线', '1号线', '7号线', '9号线'},
#   'neighbours': {'竹子林站': {'line': '1号线'},
#    '香蜜湖站': {'line': '1号线'},
#    '上沙站': {'line': '7号线'},
#    '农林站': {'line': '7号线'},
#    '香梅站': {'line': '9号线'},
#    '下沙站': {'line': '9号线'},
#    '红树湾南站': {'line': '11号线'},
#    '福田站': {'line': '11号线'}}},
#  '竹子林站': {'line': {'1号线'},
#   'neighbours': {'侨城东站': {'line': '1号线'}, '车公庙站': {'line': '1号线'}}},
#  '侨城东站': {'line': {'1号线'},
#   'neighbours': {'华侨城站': {'line': '1号线'}, '竹子林站': {'line': '1号线'}}},
#  '华侨城站': {'line': {'1号线'},
#   'neighbours': {'世界之窗站': {'line': '1号线'}, '侨城东站': {'line': '1号线'}}},
#  '世界之窗站': {'line': {'1号线', '2号线'},
#   'neighbours': {'白石洲站': {'line': '1号线'},
#    '华侨城站': {'line': '1号线'},
#    '侨城北站': {'line': '2号线'},
#    '红树湾站': {'line': '2号线'}}},
#  '白石洲站': {'line': {'1号线'},
#   'neighbours': {'高新园站': {'line': '1号线'}, '世界之窗站': {'line': '1号线'}}},
#  '高新园站': {'line': {'1号线'},
#   'neighbours': {'深大站': {'line': '1号线'}, '白石洲站': {'line': '1号线'}}},
#  '深大站': {'line': {'1号线'},
#   'neighbours': {'桃园站': {'line': '1号线'}, '高新园站': {'line': '1号线'}}},
#  '桃园站': {'line': {'1号线'},
#   'neighbours': {'大新站': {'line': '1号线'}, '深大站': {'line': '1号线'}}},
#  '大新站': {'line': {'1号线'},
#   'neighbours': {'鲤鱼门站': {'line': '1号线'}, '桃园站': {'line': '1号线'}}},
#  '鲤鱼门站': {'line': {'1号线'},
#   'neighbours': {'前海湾站': {'line': '1号线'}, '大新站': {'line': '1号线'}}},
#  '前海湾站': {'line': {'11号线', '1号线', '5号线'},
#   'neighbours': {'新安站': {'line': '1号线'},
#    '鲤鱼门站': {'line': '1号线'},
#    '临海站': {'line': '5号线'},
#    '宝安站': {'line': '11号线'},
#    '南山站': {'line': '11号线'}}},
#  '新安站': {'line': {'1号线'},
#   'neighbours': {'宝安中心站': {'line': '1号线'}, '前海湾站': {'line': '1号线'}}},
#  '宝安中心站': {'line': {'1号线', '5号线'},
#   'neighbours': {'宝体站': {'line': '1号线'},
#    '新安站': {'line': '1号线'},
#    '翻身站': {'line': '5号线'},
#    '宝华站': {'line': '5号线'}}},
#  '宝体站': {'line': {'1号线'},
#   'neighbours': {'坪洲站': {'line': '1号线'}, '宝安中心站': {'line': '1号线'}}},
#  '坪洲站': {'line': {'1号线'},
#   'neighbours': {'西乡站': {'line': '1号线'}, '宝体站': {'line': '1号线'}}},
#  '西乡站': {'line': {'1号线'},
#   'neighbours': {'固戍站': {'line': '1号线'}, '坪洲站': {'line': '1号线'}}},
#  '固戍站': {'line': {'1号线'},
#   'neighbours': {'后瑞站': {'line': '1号线'}, '西乡站': {'line': '1号线'}}},
#  '后瑞站': {'line': {'1号线'},
#   'neighbours': {'机场东站': {'line': '1号线'}, '固戍站': {'line': '1号线'}}},
#  '机场东站': {'line': {'1号线'}, 'neighbours': {'后瑞站': {'line': '1号线'}}},
#  '赤湾站': {'line': {'2号线'}, 'neighbours': {'蛇口港站': {'line': '2号线'}}},
#  '蛇口港站': {'line': {'2号线'},
#   'neighbours': {'海上世界站': {'line': '2号线'}, '赤湾站': {'line': '2号线'}}},
#  '海上世界站': {'line': {'2号线'},
#   'neighbours': {'水湾站': {'line': '2号线'}, '蛇口港站': {'line': '2号线'}}},
#  '水湾站': {'line': {'2号线'},
#   'neighbours': {'东角头站': {'line': '2号线'}, '海上世界站': {'line': '2号线'}}},
#  '东角头站': {'line': {'2号线'},
#   'neighbours': {'湾厦站': {'line': '2号线'}, '水湾站': {'line': '2号线'}}},
#  '湾厦站': {'line': {'2号线'},
#   'neighbours': {'海月站': {'line': '2号线'}, '东角头站': {'line': '2号线'}}},
#  '海月站': {'line': {'2号线'},
#   'neighbours': {'登良站': {'line': '2号线'}, '湾厦站': {'line': '2号线'}}},
#  '登良站': {'line': {'2号线'},
#   'neighbours': {'后海站': {'line': '2号线'}, '海月站': {'line': '2号线'}}},
#  '后海站': {'line': {'11号线', '2号线'},
#   'neighbours': {'科苑站': {'line': '2号线'},
#    '登良站': {'line': '2号线'},
#    '南山站': {'line': '11号线'},
#    '红树湾南站': {'line': '11号线'}}},
#  '科苑站': {'line': {'2号线'},
#   'neighbours': {'红树湾站': {'line': '2号线'}, '后海站': {'line': '2号线'}}},
#  '红树湾站': {'line': {'2号线'},
#   'neighbours': {'世界之窗站': {'line': '2号线'}, '科苑站': {'line': '2号线'}}},
#  '侨城北站': {'line': {'2号线'},
#   'neighbours': {'深康站': {'line': '2号线'}, '世界之窗站': {'line': '2号线'}}},
#  '深康站': {'line': {'2号线'},
#   'neighbours': {'安托山站': {'line': '2号线'}, '侨城北站': {'line': '2号线'}}},
#  '安托山站': {'line': {'2号线', '7号线'},
#   'neighbours': {'侨香站': {'line': '2号线'},
#    '深康站': {'line': '2号线'},
#    '农林站': {'line': '7号线'},
#    '深云站': {'line': '7号线'}}},
#  '侨香站': {'line': {'2号线'},
#   'neighbours': {'香蜜站': {'line': '2号线'}, '安托山站': {'line': '2号线'}}},
#  '香蜜站': {'line': {'2号线'},
#   'neighbours': {'香梅北站': {'line': '2号线'}, '侨香站': {'line': '2号线'}}},
#  '香梅北站': {'line': {'2号线'},
#   'neighbours': {'景田站': {'line': '2号线'}, '香蜜站': {'line': '2号线'}}},
#  '景田站': {'line': {'2号线', '9号线'},
#   'neighbours': {'莲花西站': {'line': '2号线'},
#    '香梅北站': {'line': '2号线'},
#    '梅景站': {'line': '9号线'},
#    '香梅站': {'line': '9号线'}}},
#  '莲花西站': {'line': {'2号线'},
#   'neighbours': {'福田站': {'line': '2号线'}, '景田站': {'line': '2号线'}}},
#  '福田站': {'line': {'11号线', '2号线', '3号线'},
#   'neighbours': {'市民中心站': {'line': '2号线'},
#    '莲花西站': {'line': '2号线'},
#    '少年宫站': {'line': '3号线'},
#    '购物公园站': {'line': '3号线'},
#    '车公庙站': {'line': '11号线'}}},
#  '市民中心站': {'line': {'2号线', '4号线'},
#   'neighbours': {'岗厦北站': {'line': '2号线'},
#    '福田站': {'line': '2号线'},
#    '少年宫站': {'line': '4号线'},
#    '会展中心站': {'line': '4号线'}}},
#  '岗厦北站': {'line': {'2号线'},
#   'neighbours': {'华强北站': {'line': '2号线'}, '市民中心站': {'line': '2号线'}}},
#  '华强北站': {'line': {'2号线', '7号线'},
#   'neighbours': {'燕南站': {'line': '2号线'},
#    '岗厦北站': {'line': '2号线'},
#    '华新站': {'line': '7号线'},
#    '华强南站': {'line': '7号线'}}},
#  '燕南站': {'line': {'2号线'},
#   'neighbours': {'大剧院站': {'line': '2号线'}, '华强北站': {'line': '2号线'}}},
#  '湖贝站': {'line': {'2号线'},
#   'neighbours': {'黄贝岭站': {'line': '2号线'}, '大剧院站': {'line': '2号线'}}},
#  '黄贝岭站': {'line': {'2号线', '5号线'},
#   'neighbours': {'新秀站': {'line': '2号线'},
#    '湖贝站': {'line': '2号线'},
#    '怡景站': {'line': '5号线'}}},
#  '新秀站': {'line': {'2号线'}, 'neighbours': {'黄贝岭站': {'line': '2号线'}}},
#  '益田站': {'line': {'3号线'}, 'neighbours': {'石厦站': {'line': '3号线'}}},
#  '石厦站': {'line': {'3号线', '7号线'},
#   'neighbours': {'购物公园站': {'line': '3号线'},
#    '益田站': {'line': '3号线'},
#    '皇岗村站': {'line': '7号线'},
#    '沙尾站': {'line': '7号线'}}},
#  '少年宫站': {'line': {'3号线', '4号线'},
#   'neighbours': {'莲花村站': {'line': '3号线'},
#    '福田站': {'line': '3号线'},
#    '莲花北站': {'line': '4号线'},
#    '市民中心站': {'line': '4号线'}}},
#  '莲花村站': {'line': {'3号线'},
#   'neighbours': {'华新站': {'line': '3号线'}, '少年宫站': {'line': '3号线'}}},
#  '华新站': {'line': {'3号线', '7号线'},
#   'neighbours': {'通新岭站': {'line': '3号线'},
#    '莲花村站': {'line': '3号线'},
#    '黄木岗站': {'line': '7号线'},
#    '华强北站': {'line': '7号线'}}},
#  '通新岭站': {'line': {'3号线'},
#   'neighbours': {'红岭站': {'line': '3号线'}, '华新站': {'line': '3号线'}}},
#  '红岭站': {'line': {'3号线', '9号线'},
#   'neighbours': {'老街站': {'line': '3号线'},
#    '通新岭站': {'line': '3号线'},
#    '红岭南站': {'line': '9号线'},
#    '园岭站': {'line': '9号线'}}},
#  '晒布站': {'line': {'3号线'},
#   'neighbours': {'翠竹站': {'line': '3号线'}, '老街站': {'line': '3号线'}}},
#  '翠竹站': {'line': {'3号线'},
#   'neighbours': {'田贝站': {'line': '3号线'}, '晒布站': {'line': '3号线'}}},
#  '田贝站': {'line': {'3号线', '7号线'},
#   'neighbours': {'水贝站': {'line': '3号线'},
#    '翠竹站': {'line': '3号线'},
#    '太安站': {'line': '7号线'},
#    '洪湖站': {'line': '7号线'}}},
#  '水贝站': {'line': {'3号线'},
#   'neighbours': {'草埔站': {'line': '3号线'}, '田贝站': {'line': '3号线'}}},
#  '草埔站': {'line': {'3号线'},
#   'neighbours': {'布吉站': {'line': '3号线'}, '水贝站': {'line': '3号线'}}},
#  '布吉站': {'line': {'3号线', '5号线'},
#   'neighbours': {'木棉湾站': {'line': '3号线'},
#    '草埔站': {'line': '3号线'},
#    '百鸽笼站': {'line': '5号线'},
#    '长龙站': {'line': '5号线'}}},
#  '木棉湾站': {'line': {'3号线'},
#   'neighbours': {'大芬站': {'line': '3号线'}, '布吉站': {'line': '3号线'}}},
#  '大芬站': {'line': {'3号线'},
#   'neighbours': {'丹竹头站': {'line': '3号线'}, '木棉湾站': {'line': '3号线'}}},
#  '丹竹头站': {'line': {'3号线'},
#   'neighbours': {'六约站': {'line': '3号线'}, '大芬站': {'line': '3号线'}}},
#  '六约站': {'line': {'3号线'},
#   'neighbours': {'塘坑站': {'line': '3号线'}, '丹竹头站': {'line': '3号线'}}},
#  '塘坑站': {'line': {'3号线'},
#   'neighbours': {'横岗站': {'line': '3号线'}, '六约站': {'line': '3号线'}}},
#  '横岗站': {'line': {'3号线'},
#   'neighbours': {'永湖站': {'line': '3号线'}, '塘坑站': {'line': '3号线'}}},
#  '永湖站': {'line': {'3号线'},
#   'neighbours': {'荷坳站': {'line': '3号线'}, '横岗站': {'line': '3号线'}}},
#  '荷坳站': {'line': {'3号线'},
#   'neighbours': {'大运站': {'line': '3号线'}, '永湖站': {'line': '3号线'}}},
#  '大运站': {'line': {'3号线'},
#   'neighbours': {'爱联站': {'line': '3号线'}, '荷坳站': {'line': '3号线'}}},
#  '爱联站': {'line': {'3号线'},
#   'neighbours': {'吉祥站': {'line': '3号线'}, '大运站': {'line': '3号线'}}},
#  '吉祥站': {'line': {'3号线'},
#   'neighbours': {'龙城广场站': {'line': '3号线'}, '爱联站': {'line': '3号线'}}},
#  '龙城广场站': {'line': {'3号线'},
#   'neighbours': {'南联站': {'line': '3号线'}, '吉祥站': {'line': '3号线'}}},
#  '南联站': {'line': {'3号线'},
#   'neighbours': {'双龙站': {'line': '3号线'}, '龙城广场站': {'line': '3号线'}}},
#  '双龙站': {'line': {'3号线'}, 'neighbours': {'南联站': {'line': '3号线'}}},
#  '福田口岸站': {'line': {'4号线'}, 'neighbours': {'福民站': {'line': '4号线'}}},
#  '福民站': {'line': {'4号线', '7号线'},
#   'neighbours': {'会展中心站': {'line': '4号线'},
#    '福田口岸站': {'line': '4号线'},
#    '皇岗口岸站': {'line': '7号线'},
#    '皇岗村站': {'line': '7号线'}}},
#  '莲花北站': {'line': {'4号线'},
#   'neighbours': {'上梅林站': {'line': '4号线'}, '少年宫站': {'line': '4号线'}}},
#  '上梅林站': {'line': {'4号线', '9号线'},
#   'neighbours': {'民乐站': {'line': '4号线'},
#    '莲花北站': {'line': '4号线'},
#    '孖岭站': {'line': '9号线'},
#    '梅村站': {'line': '9号线'}}},
#  '民乐站': {'line': {'4号线'},
#   'neighbours': {'白石龙站': {'line': '4号线'}, '上梅林站': {'line': '4号线'}}},
#  '白石龙站': {'line': {'4号线'},
#   'neighbours': {'深圳北站': {'line': '4号线'}, '民乐站': {'line': '4号线'}}},
#  '深圳北站': {'line': {'4号线', '5号线'},
#   'neighbours': {'红山站': {'line': '4号线'},
#    '白石龙站': {'line': '4号线'},
#    '民治站': {'line': '5号线'},
#    '长岭陂站': {'line': '5号线'}}},
#  '红山站': {'line': {'4号线'},
#   'neighbours': {'上塘站': {'line': '4号线'}, '深圳北站': {'line': '4号线'}}},
#  '上塘站': {'line': {'4号线'},
#   'neighbours': {'龙胜站': {'line': '4号线'}, '红山站': {'line': '4号线'}}},
#  '龙胜站': {'line': {'4号线'},
#   'neighbours': {'龙华站': {'line': '4号线'}, '上塘站': {'line': '4号线'}}},
#  '龙华站': {'line': {'4号线'},
#   'neighbours': {'清湖站': {'line': '4号线'}, '龙胜站': {'line': '4号线'}}},
#  '清湖站': {'line': {'4号线'}, 'neighbours': {'龙华站': {'line': '4号线'}}},
#  '临海站': {'line': {'5号线'},
#   'neighbours': {'宝华站': {'line': '5号线'}, '前海湾站': {'line': '5号线'}}},
#  '宝华站': {'line': {'5号线'},
#   'neighbours': {'宝安中心站': {'line': '5号线'}, '临海站': {'line': '5号线'}}},
#  '翻身站': {'line': {'5号线'},
#   'neighbours': {'灵芝站': {'line': '5号线'}, '宝安中心站': {'line': '5号线'}}},
#  '灵芝站': {'line': {'5号线'},
#   'neighbours': {'洪浪北站': {'line': '5号线'}, '翻身站': {'line': '5号线'}}},
#  '洪浪北站': {'line': {'5号线'},
#   'neighbours': {'兴东站': {'line': '5号线'}, '灵芝站': {'line': '5号线'}}},
#  '兴东站': {'line': {'5号线'},
#   'neighbours': {'留仙洞站': {'line': '5号线'}, '洪浪北站': {'line': '5号线'}}},
#  '留仙洞站': {'line': {'5号线'},
#   'neighbours': {'西丽站': {'line': '5号线'}, '兴东站': {'line': '5号线'}}},
#  '西丽站': {'line': {'5号线', '7号线'},
#   'neighbours': {'大学城站': {'line': '5号线'},
#    '留仙洞站': {'line': '5号线'},
#    '茶光站': {'line': '7号线'},
#    '西丽湖站': {'line': '7号线'}}},
#  '大学城站': {'line': {'5号线'},
#   'neighbours': {'塘朗站': {'line': '5号线'}, '西丽站': {'line': '5号线'}}},
#  '塘朗站': {'line': {'5号线'},
#   'neighbours': {'长岭陂站': {'line': '5号线'}, '大学城站': {'line': '5号线'}}},
#  '长岭陂站': {'line': {'5号线'},
#   'neighbours': {'深圳北站': {'line': '5号线'}, '塘朗站': {'line': '5号线'}}},
#  '民治站': {'line': {'5号线'},
#   'neighbours': {'五和站': {'line': '5号线'}, '深圳北站': {'line': '5号线'}}},
#  '五和站': {'line': {'5号线'},
#   'neighbours': {'坂田站': {'line': '5号线'}, '民治站': {'line': '5号线'}}},
#  '坂田站': {'line': {'5号线'},
#   'neighbours': {'杨美站': {'line': '5号线'}, '五和站': {'line': '5号线'}}},
#  '杨美站': {'line': {'5号线'},
#   'neighbours': {'上水径站': {'line': '5号线'}, '坂田站': {'line': '5号线'}}},
#  '上水径站': {'line': {'5号线'},
#   'neighbours': {'下水径站': {'line': '5号线'}, '杨美站': {'line': '5号线'}}},
#  '下水径站': {'line': {'5号线'},
#   'neighbours': {'长龙站': {'line': '5号线'}, '上水径站': {'line': '5号线'}}},
#  '长龙站': {'line': {'5号线'},
#   'neighbours': {'布吉站': {'line': '5号线'}, '下水径站': {'line': '5号线'}}},
#  '百鸽笼站': {'line': {'5号线'},
#   'neighbours': {'布心站': {'line': '5号线'}, '布吉站': {'line': '5号线'}}},
#  '布心站': {'line': {'5号线'},
#   'neighbours': {'太安站': {'line': '5号线'}, '百鸽笼站': {'line': '5号线'}}},
#  '太安站': {'line': {'5号线', '7号线'},
#   'neighbours': {'怡景站': {'line': '5号线'},
#    '布心站': {'line': '5号线'},
#    '田贝站': {'line': '7号线'}}},
#  '怡景站': {'line': {'5号线'},
#   'neighbours': {'黄贝岭站': {'line': '5号线'}, '太安站': {'line': '5号线'}}},
#  '西丽湖站': {'line': {'7号线'}, 'neighbours': {'西丽站': {'line': '7号线'}}},
#  '茶光站': {'line': {'7号线'},
#   'neighbours': {'珠光站': {'line': '7号线'}, '西丽站': {'line': '7号线'}}},
#  '珠光站': {'line': {'7号线'},
#   'neighbours': {'龙井站': {'line': '7号线'}, '茶光站': {'line': '7号线'}}},
#  '龙井站': {'line': {'7号线'},
#   'neighbours': {'桃源村站': {'line': '7号线'}, '珠光站': {'line': '7号线'}}},
#  '桃源村站': {'line': {'7号线'},
#   'neighbours': {'深云站': {'line': '7号线'}, '龙井站': {'line': '7号线'}}},
#  '深云站': {'line': {'7号线'},
#   'neighbours': {'安托山站': {'line': '7号线'}, '桃源村站': {'line': '7号线'}}},
#  '农林站': {'line': {'7号线'},
#   'neighbours': {'车公庙站': {'line': '7号线'}, '安托山站': {'line': '7号线'}}},
#  '上沙站': {'line': {'7号线'},
#   'neighbours': {'沙尾站': {'line': '7号线'}, '车公庙站': {'line': '7号线'}}},
#  '沙尾站': {'line': {'7号线'},
#   'neighbours': {'石厦站': {'line': '7号线'}, '上沙站': {'line': '7号线'}}},
#  '皇岗村站': {'line': {'7号线'},
#   'neighbours': {'福民站': {'line': '7号线'}, '石厦站': {'line': '7号线'}}},
#  '皇岗口岸站': {'line': {'7号线'},
#   'neighbours': {'福邻站': {'line': '7号线'}, '福民站': {'line': '7号线'}}},
#  '福邻站': {'line': {'7号线'},
#   'neighbours': {'赤尾站': {'line': '7号线'}, '皇岗口岸站': {'line': '7号线'}}},
#  '赤尾站': {'line': {'7号线'},
#   'neighbours': {'华强南站': {'line': '7号线'}, '福邻站': {'line': '7号线'}}},
#  '华强南站': {'line': {'7号线'},
#   'neighbours': {'华强北站': {'line': '7号线'}, '赤尾站': {'line': '7号线'}}},
#  '黄木岗站': {'line': {'7号线'},
#   'neighbours': {'八卦岭站': {'line': '7号线'}, '华新站': {'line': '7号线'}}},
#  '八卦岭站': {'line': {'7号线'},
#   'neighbours': {'红岭北站': {'line': '7号线'}, '黄木岗站': {'line': '7号线'}}},
#  '红岭北站': {'line': {'7号线', '9号线'},
#   'neighbours': {'笋岗站': {'line': '7号线'},
#    '八卦岭站': {'line': '7号线'},
#    '园岭站': {'line': '9号线'},
#    '泥岗站': {'line': '9号线'}}},
#  '笋岗站': {'line': {'7号线'},
#   'neighbours': {'洪湖站': {'line': '7号线'}, '红岭北站': {'line': '7号线'}}},
#  '洪湖站': {'line': {'7号线'},
#   'neighbours': {'田贝站': {'line': '7号线'}, '笋岗站': {'line': '7号线'}}},
#  '红树湾南站': {'line': {'11号线', '9号线'},
#   'neighbours': {'深湾站': {'line': '9号线'},
#    '后海站': {'line': '11号线'},
#    '车公庙站': {'line': '11号线'}}},
#  '深湾站': {'line': {'9号线'},
#   'neighbours': {'深圳湾公园站': {'line': '9号线'}, '红树湾南站': {'line': '9号线'}}},
#  '深圳湾公园站': {'line': {'9号线'},
#   'neighbours': {'下沙站': {'line': '9号线'}, '深湾站': {'line': '9号线'}}},
#  '下沙站': {'line': {'9号线'},
#   'neighbours': {'车公庙站': {'line': '9号线'}, '深圳湾公园站': {'line': '9号线'}}},
#  '香梅站': {'line': {'9号线'},
#   'neighbours': {'景田站': {'line': '9号线'}, '车公庙站': {'line': '9号线'}}},
#  '梅景站': {'line': {'9号线'},
#   'neighbours': {'下梅林站': {'line': '9号线'}, '景田站': {'line': '9号线'}}},
#  '下梅林站': {'line': {'9号线'},
#   'neighbours': {'梅村站': {'line': '9号线'}, '梅景站': {'line': '9号线'}}},
#  '梅村站': {'line': {'9号线'},
#   'neighbours': {'上梅林站': {'line': '9号线'}, '下梅林站': {'line': '9号线'}}},
#  '孖岭站': {'line': {'9号线'},
#   'neighbours': {'银湖站': {'line': '9号线'}, '上梅林站': {'line': '9号线'}}},
#  '银湖站': {'line': {'9号线'},
#   'neighbours': {'泥岗站': {'line': '9号线'}, '孖岭站': {'line': '9号线'}}},
#  '泥岗站': {'line': {'9号线'},
#   'neighbours': {'红岭北站': {'line': '9号线'}, '银湖站': {'line': '9号线'}}},
#  '园岭站': {'line': {'9号线'},
#   'neighbours': {'红岭站': {'line': '9号线'}, '红岭北站': {'line': '9号线'}}},
#  '红岭南站': {'line': {'9号线'},
#   'neighbours': {'鹿丹村站': {'line': '9号线'}, '红岭站': {'line': '9号线'}}},
#  '鹿丹村站': {'line': {'9号线'},
#   'neighbours': {'人民南站': {'line': '9号线'}, '红岭南站': {'line': '9号线'}}},
#  '人民南站': {'line': {'9号线'},
#   'neighbours': {'向西村站': {'line': '9号线'}, '鹿丹村站': {'line': '9号线'}}},
#  '向西村站': {'line': {'9号线'},
#   'neighbours': {'文锦站': {'line': '9号线'}, '人民南站': {'line': '9号线'}}},
#  '文锦站': {'line': {'9号线'}, 'neighbours': {'向西村站': {'line': '9号线'}}},
#  '南山站': {'line': {'11号线'},
#   'neighbours': {'前海湾站': {'line': '11号线'}, '后海站': {'line': '11号线'}}},
#  '宝安站': {'line': {'11号线'},
#   'neighbours': {'碧海湾站': {'line': '11号线'}, '前海湾站': {'line': '11号线'}}},
#  '碧海湾站': {'line': {'11号线'},
#   'neighbours': {'机场站': {'line': '11号线'}, '宝安站': {'line': '11号线'}}},
#  '机场站': {'line': {'11号线'},
#   'neighbours': {'机场北站': {'line': '11号线'}, '碧海湾站': {'line': '11号线'}}},
#  '机场北站': {'line': {'11号线'},
#   'neighbours': {'福永站': {'line': '11号线'}, '机场站': {'line': '11号线'}}},
#  '福永站': {'line': {'11号线'},
#   'neighbours': {'桥头站': {'line': '11号线'}, '机场北站': {'line': '11号线'}}},
#  '桥头站': {'line': {'11号线'},
#   'neighbours': {'塘尾站': {'line': '11号线'}, '福永站': {'line': '11号线'}}},
#  '塘尾站': {'line': {'11号线'},
#   'neighbours': {'马安山站': {'line': '11号线'}, '桥头站': {'line': '11号线'}}},
#  '马安山站': {'line': {'11号线'},
#   'neighbours': {'沙井站': {'line': '11号线'}, '塘尾站': {'line': '11号线'}}},
#  '沙井站': {'line': {'11号线'},
#   'neighbours': {'后亭站': {'line': '11号线'}, '马安山站': {'line': '11号线'}}},
#  '后亭站': {'line': {'11号线'},
#   'neighbours': {'松岗站': {'line': '11号线'}, '沙井站': {'line': '11号线'}}},
#  '松岗站': {'line': {'11号线'},
#   'neighbours': {'碧头站': {'line': '11号线'}, '后亭站': {'line': '11号线'}}},
#  '碧头站': {'line': {'11号线'}, 'neighbours': {'松岗站': {'line': '11号线'}}}}

# %%
import queue
import copy

# %%
def _search_path(state, dst,success_plan):
    def update_state_with_site(site, new_line):
        """更新当前方案的权重信息"""
        new_state = copy.deepcopy(state)
        # cur = new_state["path"][-1]
        # if not subway_site_map.get(cur):
        #     cur = new_state["path"][-2]
        new_state['sites'] += 1
        if len(new_state["path"]) >= 2:
            a2site = new_state["path"][-2]
            if not subway_site_map.get(a2site):
                a2site = new_state["path"][-3]
            if new_line not in subway_site_map[a2site]['line']:
                new_state['lines'] += 1
                new_state['path'].append("(换乘%s)" % new_line)
        new_state['path'].append(site)
        return new_state

    def is_good_plan(new_state):
        """
        根据已经找到的方案判断是否值得搜索，剪枝以减少搜索范围
        :param next_site:
        :return:
        """
        if len(success_plan) == 0:
            return True, "not found plan yet"
        min_sites = min(i["sites"] for i in success_plan)
        min_lines = min(i["lines"] for i in success_plan)
        if new_state["sites"] < min_sites:
                return True, "sites %s < %s" % (new_state["sites"], min_sites)
        elif new_state["lines"] < min_lines:
                return True, "lines %s < %s" % (new_state["lines"], min_lines)
        return False, "Stop"

    cur = state["path"][-1]
    if not subway_site_map.get(cur):
        cur = state["path"][-2]
    # 返回搜索的方案
    for next_site, v in subway_site_map[cur]["neighbours"].items():
        if next_site in state["path"]:
            continue
        path = state["path"] + [next_site]
        # print('-->'.join(path))
        new_line = v["line"]
        if next_site == dst:
            # 到达目的地
            # print("Found!!!")
            yield True, update_state_with_site(next_site, new_line)
        else:
            new_state = update_state_with_site(next_site, new_line)
            # 剪枝以减少搜索
            isgood, msg = is_good_plan(new_state)
            # print(msg)
            if isgood:
                yield False, new_state

# %%
def search(src, dst, prefer="最少站点"):
    search_task = queue.Queue()  # BFS 搜索
    init_state = {
        # 当前的路径
        "path": [src],
        # 当前方案的站点数
        "sites": 1,
        # 当前方案的换乘数
        "lines": 1,
        # 当前方案的距离
        "dist": 0,
        # 当前方案的时长
        "time_cost": 0,

    }
    search_task.put(init_state)
    success_plan = []  # 搜索到的方案
    while not search_task.empty():
        p = search_task.get()
        for if_found, plan in _search_path(p, dst, success_plan):
            if if_found:
                success_plan.append(plan)
            else:
                search_task.put(plan)
    if len(success_plan) == 0:
        print("没有找到合适的方案！")
        return
    elif prefer == "最少站点":
        plan = sorted(success_plan, key=lambda x: x['sites'])[0]
    elif prefer == "最少换乘":
        plan = sorted(success_plan, key=lambda x: x['lines'])[0]
    print("已经为您找到方案：")
    print('-->'.join(plan["path"]))
    print("总站点数：%d, 需要换乘 %d 次" % (plan["sites"], plan["lines"] - 1))

# %%
search("深康站", "农林站")
# Out:
# 已经为您找到方案：
# 深康站-->安托山站-->(换乘7号线)-->农林站
# 总站点数：3, 需要换乘 1 次

# %%
search("坂田站", "科苑站", "最少站点")
# Out:
# 已经为您找到方案：
# 坂田站-->五和站-->民治站-->深圳北站-->(换乘4号线)-->白石龙站-->民乐站-->上梅林站-->莲花北站-->少年宫站-->(换乘3号线)-->福田站-->(换乘11号线)-->车公庙站-->红树湾南站-->后海站-->(换乘2号线)-->科苑站
# 总站点数：14, 需要换乘 4 次

# %%
search("坂田站", "科苑站", "最少换乘")
# Out:
# 已经为您找到方案：
# 坂田站-->杨美站-->上水径站-->下水径站-->长龙站-->布吉站-->百鸽笼站-->布心站-->太安站-->怡景站-->黄贝岭站-->(换乘2号线)-->湖贝站-->大剧院站-->燕南站-->华强北站-->岗厦北站-->市民中心站-->福田站-->莲花西站-->景田站-->香梅北站-->香蜜站-->侨香站-->安托山站-->深康站-->侨城北站-->世界之窗站-->红树湾站-->科苑站
# 总站点数：29, 需要换乘 1 次
